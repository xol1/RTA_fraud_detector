# %%
import json
import random
import uuid
from datetime import datetime, timedelta

def generuj_i_zapisz_do_json(nazwa_pliku, liczba_rekordow=100):
    miasta = [
    'Warszawa', 'Kraków', 'Łódź', 'Wrocław', 'Poznań', 
    'Gdańsk', 'Szczecin', 'Bydgoszcz', 'Lublin', 'Białystok', 
    'Katowice', 'Gdynia', 'Częstochowa', 'Radom', 'Sosnowiec', 
    'Toruń', 'Kielce', 'Rzeszów', 'Gliwice', 'Zabrze', 
    'Olsztyn', 'Bielsko-Biała', 'Bytom', 'Zielona Góra', 'Rybnik', 
    'Ruda Śląska', 'Tychy', 'Gorzów Wielkopolski', 'Dąbrowa Górnicza', 'Elbląg', 
    'Płock', 'Opole', 'Wałbrzych', 'Włocławek', 'Tarnów', 
    'Chorzów', 'Koszalin', 'Kalisz', 'Legnica', 'Grudziądz', 
    'Jaworzno', 'Słupsk', 'Jastrzębie-Zdrój', 'Nowy Sącz', 'Jelenia Góra', 
    'Siedlce', 'Mysłowice', 'Konin', 'Piła', 'Piotrków Trybunalski']
    imiona_k = [
    "Ada", "Agata", "Agnieszka", "Aleksandra", "Alicja", "Alina", "Amelia", "Anastazja", 
    "Aneta", "Anna", "Antonina", "Aurelia", "Barbara", "Beata", "Blanka", "Bogumiła", 
    "Bożena", "Celina", "Dagmara", "Danuta", "Daria", "Diana", "Dominika", "Dorota", 
    "Edyta", "Eliza", "Elżbieta", "Emilia", "Ewa", "Ewelina", "Gabriela", "Grażyna", 
    "Halina", "Hanna", "Helena", "Iga", "Ines", "Irena", "Iwona", "Izabela", "Jadwiga", 
    "Jagoda", "Janina", "Joanna", "Jolanta", "Jowita", "Judyta", "Julia", "Justyna", 
    "Kamila", "Karolina", "Katarzyna", "Kinga", "Klara", "Klaudia", "Kornelia", "Krystyna", 
    "Laura", "Lidia", "Liliana", "Liwia", "Łucja", "Magdalena", "Maja", "Malwina", 
    "Małgorzata", "Marcelina", "Maria", "Marianna", "Marta", "Martyna", "Maryla", "Marzena", 
    "Matylda", "Michalina", "Milena", "Monika", "Nadia", "Natalia", "Nela", "Nina", 
    "Oliwia", "Patrycja", "Paula", "Paulina", "Pola", "Renata", "Roksana", "Róża", 
    "Sabina", "Stanisława", "Stefania", "Sylwia", "Teresa", "Urszula", "Wanda", "Weronika", 
    "Wiktoria", "Zofia", "Zuzanna"]

    imiona_m = [
    "Adam", "Adrian", "Albert", "Aleksander", "Amadeusz", "Andrzej", "Antoni", "Arkadiusz", 
    "Artur", "Bartłomiej", "Bartosz", "Błażej", "Bogdan", "Bogusław", "Borys", "Bronisław", 
    "Cezary", "Czesław", "Damian", "Daniel", "Dariusz", "Dawid", "Dominik", "Edward", 
    "Eryk", "Eugeniusz", "Fabian", "Filip", "Franciszek", "Gabriel", "Grzegorz", "Gustaw", 
    "Henryk", "Hubert", "Ignacy", "Igor", "Ireneusz", "Jacek", "Jakub", "Jan", "Janusz", 
    "Jarosław", "Jerzy", "Joachim", "Józef", "Julian", "Juliusz", "Kacper", "Kamil", 
    "Karol", "Kazimierz", "Krystian", "Krzysztof", "Leon", "Leszek", "Lucjan", "Łukasz", 
    "Maciej", "Maksymilian", "Marcel", "Marcin", "Marek", "Marian", "Mariusz", "Mateusz", 
    "Michał", "Mikołaj", "Miłosz", "Mirosław", "Nikodem", "Norbert", "Olaf", "Olgierd", 
    "Oskar", "Patryk", "Paweł", "Piotr", "Przemysław", "Radosław", "Rafał", "Robert", 
    "Roman", "Ryszard", "Sebastian", "Seweryn", "Sławomir", "Stanisław", "Stefan", "Sylwester", 
    "Szczepan", "Szymon", "Tadeusz", "Tomasz", "Tymoteusz", "Wacław", "Waldemar", "Wiesław", 
    "Wiktor", "Wojciech", "Zbigniew"]
    nazwiska = [
    'Nowak', 'Kowalski', 'Wiśniewski', 'Wójcik', 'Kowalczyk', 'Kamiński', 'Lewandowski', 
    'Zieliński', 'Szymański', 'Woźniak', 'Dąbrowski', 'Kozłowski', 'Jankowski', 'Mazur', 
    'Wojciechowski', 'Kwiatkowski', 'Krawczyk', 'Kaczmarek', 'Piotrowski', 'Grabowski', 
    'Zając', 'Pawłowski', 'Michalski', 'Król', 'Wieczorek', 'Jabłoński', 'Wróbel', 
    'Nowakowski', 'Majewski', 'Olszewski', 'Stępień', 'Malinowski', 'Jaworski', 'Adamczyk', 
    'Dudek', 'Górecki', 'Sikora', 'Walczak', 'Rutkowski', 'Michalak', 'Szewczyk', 
    'Ostrowski', 'Tomaszewski', 'Zalewski', 'Wróblewski', 'Piotrowicz', 'Jastrzębski', 
    'Marciniak', 'Sadowski', 'Zawadzki', 'Bąk', 'Jakubowski', 'Wilk', 'Chmielewski', 
    'Włodarczyk', 'Borkowski', 'Czarnecki', 'Maciejewski', 'Kaczmarczyk', 'Urbański', 
    'Szczepański', 'Kubiak', 'Kalinowski', 'Mróz', 'Lis', 'Klimek', 'Gajewski', 'Kurek', 
    'Wysocki', 'Baran', 'Bogusz', 'Kozak', 'Mazurek', 'Sobczak', 'Konieczny', 'Kołodziej', 
    'Cieślak', 'Głowacki', 'Zakrzewski', 'Szulc', 'Sikorski', 'Makowski', 'Baranowski', 
    'Szymczak', 'Kania', 'Laskowski', 'Janik', 'Kaczor', 'Szczęsny', 'Gajda', 
    'Błaszczyk', 'Janowski', 'Szydłowski', 'Dziedzic', 'Kozieł', 'Leszczyński', 'Lipiński', 
    'Kowal', 'Mikołajczyk', 'Zarzycki']
    typy_kont = ['Standard', 'Premium', 'Student', 'Oszczędnościowe', 'VIP']

    klienci = []

    for _ in range(liczba_rekordow):
        plec = random.choice(['M', 'K'])
        imie = random.choice(imiona_m if plec == 'M' else imiona_k)
        
        # Prosta logika końcówek nazwisk dla kobiet (opcjonalnie)
        nazwisko = random.choice(nazwiska)
        if plec == 'K' and nazwisko.endswith('i'):
            nazwisko = nazwisko[:-1] + 'a'

        klient = {
            "id": str(uuid.uuid4())[:8], # Skrócone ID dla czytelności
            "imie": imie,
            "nazwisko": nazwisko,
            "miasto": random.choice(miasta),
            "wiek": random.randint(18, 85),
            "saldo": round(random.uniform(-100.0, 250000.0), 2),
            "waluta": "PLN",
            "typ_konta": random.choice(typy_kont),
            "status": random.choices(["aktywne", "zablokowane", "nieaktywne"], weights=[80, 5, 15])[0],
            "ostatnie_logowanie": (datetime.now() - timedelta(days=random.randint(0, 30))).strftime("%Y-%m-%d %H:%M:%S")
        }
        klienci.append(klient)

    # Zapis do pliku JSON
    with open(nazwa_pliku, 'w', encoding='utf-8') as f:
        json.dump(klienci, f, indent=4, ensure_ascii=False)
    
    print(f"Pomyślnie zapisano {liczba_rekordow} klientów do pliku {nazwa_pliku}")

# Uruchomienie
generuj_i_zapisz_do_json('klienci_banku.json')
# Out:
# Pomyślnie zapisano 100 klientów do pliku klienci_banku.json

# %%
import random
import uuid
import json
import time
from datetime import datetime
from confluent_kafka import Producer

def generuj():
    miasta = [
    'Warszawa', 'Kraków', 'Łódź', 'Wrocław', 'Poznań', 
    'Gdańsk', 'Szczecin', 'Bydgoszcz', 'Lublin', 'Białystok', 
    'Katowice', 'Gdynia', 'Częstochowa', 'Radom', 'Sosnowiec', 
    'Toruń', 'Kielce', 'Rzeszów', 'Gliwice', 'Zabrze', 
    'Olsztyn', 'Bielsko-Biała', 'Bytom', 'Zielona Góra', 'Rybnik', 
    'Ruda Śląska', 'Tychy', 'Gorzów Wielkopolski', 'Dąbrowa Górnicza', 'Elbląg', 
    'Płock', 'Opole', 'Wałbrzych', 'Włocławek', 'Tarnów', 
    'Chorzów', 'Koszalin', 'Kalisz', 'Legnica', 'Grudziądz', 
    'Jaworzno', 'Słupsk', 'Jastrzębie-Zdrój', 'Nowy Sącz', 'Jelenia Góra', 
    'Siedlce', 'Mysłowice', 'Konin', 'Piła', 'Piotrków Trybunalski']
    
    imiona_k = [
    "Ada", "Agata", "Agnieszka", "Aleksandra", "Alicja", "Alina", "Amelia", "Anastazja", 
    "Aneta", "Anna", "Antonina", "Aurelia", "Barbara", "Beata", "Blanka", "Bogumiła", 
    "Bożena", "Celina", "Dagmara", "Danuta", "Daria", "Diana", "Dominika", "Dorota", 
    "Edyta", "Eliza", "Elżbieta", "Emilia", "Ewa", "Ewelina", "Gabriela", "Grażyna", 
    "Halina", "Hanna", "Helena", "Iga", "Ines", "Irena", "Iwona", "Izabela", "Jadwiga", 
    "Jagoda", "Janina", "Joanna", "Jolanta", "Jowita", "Judyta", "Julia", "Justyna", 
    "Kamila", "Karolina", "Katarzyna", "Kinga", "Klara", "Klaudia", "Kornelia", "Krystyna", 
    "Laura", "Lidia", "Liliana", "Liwia", "Łucja", "Magdalena", "Maja", "Malwina", 
    "Małgorzata", "Marcelina", "Maria", "Marianna", "Marta", "Martyna", "Maryla", "Marzena", 
    "Matylda", "Michalina", "Milena", "Monika", "Nadia", "Natalia", "Nela", "Nina", 
    "Oliwia", "Patrycja", "Paula", "Paulina", "Pola", "Renata", "Roksana", "Róża", 
    "Sabina", "Stanisława", "Stefania", "Sylwia", "Teresa", "Urszula", "Wanda", "Weronika", 
    "Wiktoria", "Zofia", "Zuzanna"]

    imiona_m = [
    "Adam", "Adrian", "Albert", "Aleksander", "Amadeusz", "Andrzej", "Antoni", "Arkadiusz", 
    "Artur", "Bartłomiej", "Bartosz", "Błażej", "Bogdan", "Bogusław", "Borys", "Bronisław", 
    "Cezary", "Czesław", "Damian", "Daniel", "Dariusz", "Dawid", "Dominik", "Edward", 
    "Eryk", "Eugeniusz", "Fabian", "Filip", "Franciszek", "Gabriel", "Grzegorz", "Gustaw", 
    "Henryk", "Hubert", "Ignacy", "Igor", "Ireneusz", "Jacek", "Jakub", "Jan", "Janusz", 
    "Jarosław", "Jerzy", "Joachim", "Józef", "Julian", "Juliusz", "Kacper", "Kamil", 
    "Karol", "Kazimierz", "Krystian", "Krzysztof", "Leon", "Leszek", "Lucjan", "Łukasz", 
    "Maciej", "Maksymilian", "Marcel", "Marcin", "Marek", "Marian", "Mariusz", "Mateusz", 
    "Michał", "Mikołaj", "Miłosz", "Mirosław", "Nikodem", "Norbert", "Olaf", "Olgierd", 
    "Oskar", "Patryk", "Paweł", "Piotr", "Przemysław", "Radosław", "Rafał", "Robert", 
    "Roman", "Ryszard", "Sebastian", "Seweryn", "Sławomir", "Stanisław", "Stefan", "Sylwester", 
    "Szczepan", "Szymon", "Tadeusz", "Tomasz", "Tymoteusz", "Wacław", "Waldemar", "Wiesław", 
    "Wiktor", "Wojciech", "Zbigniew"]
    
    nazwiska = [
    'Nowak', 'Kowalski', 'Wiśniewski', 'Wójcik', 'Kowalczyk', 'Kamiński', 'Lewandowski', 
    'Zieliński', 'Szymański', 'Woźniak', 'Dąbrowski', 'Kozłowski', 'Jankowski', 'Mazur', 
    'Wojciechowski', 'Kwiatkowski', 'Krawczyk', 'Kaczmarek', 'Piotrowski', 'Grabowski', 
    'Zając', 'Pawłowski', 'Michalski', 'Król', 'Wieczorek', 'Jabłoński', 'Wróbel', 
    'Nowakowski', 'Majewski', 'Olszewski', 'Stępień', 'Malinowski', 'Jaworski', 'Adamczyk', 
    'Dudek', 'Górecki', 'Sikora', 'Walczak', 'Rutkowski', 'Michalak', 'Szewczyk', 
    'Ostrowski', 'Tomaszewski', 'Zalewski', 'Wróblewski', 'Piotrowicz', 'Jastrzębski', 
    'Marciniak', 'Sadowski', 'Zawadzki', 'Bąk', 'Jakubowski', 'Wilk', 'Chmielewski', 
    'Włodarczyk', 'Borkowski', 'Czarnecki', 'Maciejewski', 'Kaczmarczyk', 'Urbański', 
    'Szczepański', 'Kubiak', 'Kalinowski', 'Mróz', 'Lis', 'Klimek', 'Gajewski', 'Kurek', 
    'Wysocki', 'Baran', 'Bogusz', 'Kozak', 'Mazurek', 'Sobczak', 'Konieczny', 'Kołodziej', 
    'Cieślak', 'Głowacki', 'Zakrzewski', 'Szulc', 'Sikorski', 'Makowski', 'Baranowski', 
    'Szymczak', 'Kania', 'Laskowski', 'Janik', 'Kaczor', 'Szczęsny', 'Gajda', 
    'Błaszczyk', 'Janowski', 'Szydłowski', 'Dziedzic', 'Kozieł', 'Leszczyński', 'Lipiński', 
    'Kowal', 'Mikołajczyk', 'Zarzycki']
    
    typy_kont = ['Standard', 'Premium', 'Student', 'Oszczędnościowe', 'VIP']

    plec = random.choice(['M', 'K'])
    imie = random.choice(imiona_m if plec == 'M' else imiona_k)
    
    nazwisko = random.choice(nazwiska)
    if plec == 'K' and nazwisko.endswith('i'):
        nazwisko = nazwisko[:-1] + 'a'

    # ZMIENIONE KLUCZE ABY PASOWAŁY DO BAZY
    klient = {
        "id_klienta": str(uuid.uuid4())[:8], 
        "imie": imie,
        "nazwisko": nazwisko,
        "miasto": random.choice(miasta),
        "wiek": random.randint(18, 85),
        "saldo_pln": round(random.uniform(-1000.0, 250000.0), 2),
        "typ_konta": random.choice(typy_kont),
        "czy_aktywne": random.choices([True, False], weights=[85, 15])[0],
        "data_zalozenia": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    }
    return klient

# Konfiguracja producenta Kafki
conf = {'bootstrap.servers': 'broker:9092'}
producer = Producer(conf)

def delivery_report(err, msg):
    if err is not None:
        print(f'Błąd: {err}')
    else:
        print(f'Wysłano do Kafki: {msg.value().decode("utf-8")}')

try:
    print("Rozpoczynam wysyłanie danych w czasie rzeczywistym... (Ctrl+C aby przerwać)")
    while True:
        klient = generuj()

        producer.produce(
            'nowi_klienci', 
            value=json.dumps(klient), 
            callback=delivery_report
        )
        producer.flush()

        time.sleep(2)

except KeyboardInterrupt:
    print("Zatrzymano.")
# Out:
# Rozpoczynam wysyłanie danych w czasie rzeczywistym... (Ctrl+C aby przerwać)
# Wysłano do Kafki: {"id_klienta": "76733da6", "imie": "Henryk", "nazwisko": "Jankowski", "miasto": "Gorz\u00f3w Wielkopolski", "wiek": 60, "saldo_pln": 101570.56, "typ_konta": "Student", "czy_aktywne": true, "data_zalozenia": "2026-05-10 11:50:59"}
# Wysłano do Kafki: {"id_klienta": "c3774598", "imie": "Seweryn", "nazwisko": "Cie\u015blak", "miasto": "D\u0105browa G\u00f3rnicza", "wiek": 67, "saldo_pln": 193921.57, "typ_konta": "Oszcz\u0119dno\u015bciowe", "czy_aktywne": true, "data_zalozenia": "2026-05-10 11:51:01"}
# Wysłano do Kafki: {"id_klienta": "17f7efa5", "imie": "Zuzanna", "nazwisko": "Zieli\u0144ska", "miasto": "Chorz\u00f3w", "wiek": 46, "saldo_pln": 36459.65, "typ_konta": "VIP", "czy_aktywne": true, "data_zalozenia": "2026-05-10 11:51:03"}
# ...
